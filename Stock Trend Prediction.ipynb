# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
# start = '2015-01-01'
# end = '2024-12-31'

# df = data.DataReader('AAPL' , 'yahoo' , start , end)
# df.head()

import yfinance as yf

# Define the start and end dates
start = '2015-01-01'
end = '2023-12-31'

# Download data for both Apple and Yahoo
tickers = ['AAPL']
df = yf.download(tickers, start=start, end=end)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.402176  212818400
# 2015-01-05  27.072500  27.162500  26.352501  26.562500  23.714724  257142000
# 2015-01-06  26.635000  26.857500  26.157499  26.565001  23.716955  263188400
# 2015-01-07  26.799999  27.049999  26.674999  26.937500  24.049517  160423600
# 2015-01-08  27.307501  28.037500  27.174999  27.972500  24.973555  237458000

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  193.091385
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  192.542831
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  192.642548
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  193.071426
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  192.024185
#
#               Volume
# Date
# 2023-12-22  37122800
# 2023-12-26  28919300
# 2023-12-27  48087700
# 2023-12-28  34049900
# 2023-12-29  42628800

# %%
df = df.reset_index()
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.402176  212818400
# 1 2015-01-05  27.072500  27.162500  26.352501  26.562500  23.714724  257142000
# 2 2015-01-06  26.635000  26.857500  26.157499  26.565001  23.716955  263188400
# 3 2015-01-07  26.799999  27.049999  26.674999  26.937500  24.049517  160423600
# 4 2015-01-08  27.307501  28.037500  27.174999  27.972500  24.973555  237458000

# %%
df = df.drop(['Date' , 'Adj Close'] , axis=1)
df.head()
# Out:
#         Open       High        Low      Close     Volume
# 0  27.847500  27.860001  26.837500  27.332500  212818400
# 1  27.072500  27.162500  26.352501  26.562500  257142000
# 2  26.635000  26.857500  26.157499  26.565001  263188400
# 3  26.799999  27.049999  26.674999  26.937500  160423600
# 4  27.307501  28.037500  27.174999  27.972500  237458000

# %%
plt.plot(df.Close)

# %%
df
# Out:
#             Open        High         Low       Close     Volume
# 0      27.847500   27.860001   26.837500   27.332500  212818400
# 1      27.072500   27.162500   26.352501   26.562500  257142000
# 2      26.635000   26.857500   26.157499   26.565001  263188400
# 3      26.799999   27.049999   26.674999   26.937500  160423600
# 4      27.307501   28.037500   27.174999   27.972500  237458000
# ...          ...         ...         ...         ...        ...
# 2259  195.179993  195.410004  192.970001  193.600006   37122800
# 2260  193.610001  193.889999  192.830002  193.050003   28919300
# 2261  192.490005  193.500000  191.089996  193.149994   48087700
# 2262  194.139999  194.660004  193.169998  193.580002   34049900
# 2263  193.899994  194.399994  191.729996  192.529999   42628800
#
# [2264 rows x 5 columns]

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 2259    181.768301
# 2260    181.787101
# 2261    181.898701
# 2262    182.046001
# 2263    182.173301
# Name: Close, Length: 2264, dtype: float64

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100 , 'r')

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 2259    178.649100
# 2260    178.871851
# 2261    179.085250
# 2262    179.290201
# 2263    179.487900
# Name: Close, Length: 2264, dtype: float64

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100 , 'r')
plt.plot(ma200 , 'g')

# %%
df.shape
# Out:
# (2264, 5)

# %%
# Splitting Data into Training and Testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (1584, 1)
# (680, 1)

# %%
data_training.head()
# Out:
#        Close
# 0  27.332500
# 1  26.562500
# 2  26.565001
# 3  26.937500
# 4  27.972500

# %%
data_testing.head()
# Out:
#            Close
# 1584  133.110001
# 1585  133.500000
# 1586  131.940002
# 1587  134.320007
# 1588  134.720001

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.03937384],
#        [0.03298777],
#        [0.03300851],
#        ...,
#        [0.92817746],
#        [0.92535766],
#        [0.93099725]])

# %%
data_training_array.shape
# Out:
# (1584, 1)

# %%
x_train = []
y_train = []

for i in range(100 , data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i , 0])

x_train , y_train = np.array(x_train) , np.array(y_train)

# %%
x_train.shape
# Out:
# (1484, 100, 1)

# %%
# ML Model

# %%
from keras.layers import Dense , Dropout , LSTM ,Input
from keras.models import Sequential

# %%
# Building the LSTM model
model = Sequential()

# Input layer
model.add(Input(shape=(x_train.shape[1], 1)))

# LSTM layers with dropout
model.add(LSTM(units=50, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=60, activation='relu', return_sequences=True))
model.add(Dropout(0.3))

model.add(LSTM(units=80, activation='relu', return_sequences=True))
model.add(Dropout(0.4))

model.add(LSTM(units=120, activation='relu'))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(units=1))

# Model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100, 80)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 120)            │        96,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           121 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Activation Function: Using 'relu' as the activation function in LSTM layers is unconventional. Typically, tanh is used for the activation function in LSTM cells, while relu is not recommended.

# %%
# from keras.models import Sequential
# from keras.layers import LSTM, Dropout, Dense, Input

# # Building the LSTM model
# model = Sequential()

# # Input layer
# model.add(Input(shape=(x_train.shape[1], 1)))

# # LSTM layers
# model.add(LSTM(units=50, activation='tanh', return_sequences=True))
# model.add(Dropout(0.2))

# model.add(LSTM(units=60, activation='tanh', return_sequences=True))
# model.add(Dropout(0.3))

# model.add(LSTM(units=80, activation='tanh', return_sequences=True))
# model.add(Dropout(0.4))

# model.add(LSTM(units=120, activation='tanh'))
# model.add(Dropout(0.5))

# # Output layer
# model.add(Dense(1))

# # Compile the model
# model.compile(optimizer='adam', loss='mean_squared_error')

# # Model summary
# model.summary()

# %%
model.compile(optimizer ='adam' , loss = 'mean_squared_error')
model.fit(x_train , y_train , epochs = 50)
# Out:
# Epoch 1/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 12s 127ms/step - loss: 0.0710
# Epoch 2/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - loss: 0.0100
# Epoch 3/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - loss: 0.0049
# Epoch 4/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - loss: 0.0055
# Epoch 5/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - loss: 0.0037
# Epoch 6/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - loss: 0.0040
# Epoch 7/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - loss: 0.0039
# Epoch 8/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - loss: 0.0043
# Epoch 9/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - loss: 0.0035
# Epoch 10/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - loss: 0.0038
# Epoch 11/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - loss: 0.0031
# Epoch 12/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 155ms/step - loss: 0.0036
# Epoch 13/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 142ms/step - loss: 0.0037
# Epoch 14/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - loss: 0.0039
# Epoch 15/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - loss: 0.0031
# Epoch 16/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - loss: 0.0031
# Epoch 17/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - loss: 0.0034
# Epoch 18/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - loss: 0.0028
# Epoch 19/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 142ms/step - loss: 0.0035
# Epoch 20/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 151ms/step - loss: 0.0033
# Epoch 21/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - loss: 0.0032
# Epoch 22/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - loss: 0.0026
# Epoch 23/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - loss: 0.0031
# Epoch 24/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - loss: 0.0030
# Epoch 25/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - loss: 0.0031
# Epoch 26/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - loss: 0.0025
# Epoch 27/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 151ms/step - loss: 0.0026
# Epoch 28/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - loss: 0.0030
# Epoch 29/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - loss: 0.0027
# Epoch 30/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - loss: 0.0028
# Epoch 31/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0024
# Epoch 32/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0026
# Epoch 33/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0025
# Epoch 34/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0021
# Epoch 35/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - loss: 0.0020
# Epoch 36/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0021
# Epoch 37/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0026
# Epoch 38/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - loss: 0.0025
# Epoch 39/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - loss: 0.0022
# Epoch 40/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - loss: 0.0018
# Epoch 41/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0021
# Epoch 42/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0023
# Epoch 43/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - loss: 0.0022
# Epoch 44/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0024
# Epoch 45/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - loss: 0.0026
# Epoch 46/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - loss: 0.0022
# Epoch 47/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - loss: 0.0025
# Epoch 48/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - loss: 0.0019
# Epoch 49/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 157ms/step - loss: 0.0020
# Epoch 50/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 0.0021

# %%
model.save('my_model.keras')

# %%
data_testing.head()
# Out:
#            Close
# 1584  133.110001
# 1585  133.500000
# 1586  131.940002
# 1587  134.320007
# 1588  134.720001

# %%
data_testing.tail(100)
# Out:
#            Close
# 2164  178.190002
# 2165  177.970001
# 2166  177.789993
# 2167  179.460007
# 2168  177.449997
# ...          ...
# 2259  193.600006
# 2260  193.050003
# 2261  193.149994
# 2262  193.580002
# 2263  192.529999
#
# [100 rows x 1 columns]

# %%
past_100_days = data_training.tail(100)

# %%
# Concatenating DataFrames

# final_df = past_100_days.append(data_testing , ignore_index=True)

final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
#         Close
# 0  113.849998
# 1  115.169998
# 2  116.029999
# 3  116.589996
# 4  119.050003

# %%
input_data = scaler.fit_transform(final_df)

# %%
input_data.shape
# Out:
# (780, 1)

# %%
x_test = []
y_test = []

for i in range(100 , input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i , 0])

# %%
x_test , y_test = np.array(x_test) , np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (680, 100, 1)
# (680,)

# %%
# Making Predictions

y_predicted = model.predict(x_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step

# %%
y_predicted.shape
# Out:
# (680, 1)

# %%
y_test
# Out:
# array([0.22857823, 0.23320675, 0.21469266, 0.24293862, 0.24768576,
#        0.24376929, 0.23415622, 0.23296934, 0.20899606, 0.22181337,
#        0.16615238, 0.16911948, 0.18858304, 0.19416102, 0.15428435,
#        0.14312847, 0.10586278, 0.1319725 , 0.16140515, 0.14740088,
#        0.1305483 , 0.12864946, 0.15974364, 0.13743178, 0.15725136,
#        0.15487779, 0.15428435, 0.13565155, 0.1277    , 0.12378353,
#        0.13304057, 0.11500121, 0.14289106, 0.14300976, 0.15297886,
#        0.15760739, 0.14550204, 0.16021837, 0.19736526, 0.18739616,
#        0.19344879, 0.21291235, 0.19712803, 0.21896516, 0.23890336,
#        0.23558032, 0.23213867, 0.22857823, 0.24839781, 0.26679329,
#        0.27427021, 0.27794927, 0.30987429, 0.3343224 , 0.3645859 ,
#        0.3488014 , 0.37099456, 0.36375505, 0.3772846 , 0.41894131,
#        0.41098975, 0.38618562, 0.33942556, 0.38333723, 0.3744362 ,
#        0.39105155, 0.41193921, 0.41704256, 0.39069553, 0.36945166,
#        [0.36869806],
#        [0.36132345],
#        [0.35402715],
#        [0.34746617],
#        [0.34191334],
#        [0.33673036],
#        [0.33091715],
#        [0.32364103],
#        [0.31447768],
#        [0.3038536 ],
#        [0.2921649 ],
#        [0.27983868],
#        [0.2672483 ],
#        [0.25444436],
#        [0.2419873 ],
#        [0.2306869 ],
#        [0.22081107],
#        [0.21258429],
#        [0.20579007],
#        [0.20009191],
#        [0.19537596],
#        [0.19158632],
#        [0.18886118],
#        [0.18731777],
#        [0.18688028],
#        [0.18748106],
#        [0.1891401 ],
#        [0.19226484],
#        [0.1973827 ],
#        [0.20486294],
#        [0.21495757],
#        [0.22744167],
#        [0.24182034],
#        [0.25776476],
#        [0.27423388],
#        [0.2902289 ],
#        [0.30504644],
#        [0.31910616],
#        [0.3335188 ],
#        [0.34855592],
#        [0.36445403],
#        [0.38058668],
#        [0.39576286],
#        [0.4088538 ],
#        [0.41967705],
#        [0.42827502],
#        [0.4352185 ],
#        [0.44076407],
#        [0.4448288 ],
#        [0.44658732],
#        [0.4456309 ],
#        [0.4421491 ],
#        [0.4363281 ],
#        [0.42873657],
#        [0.42000893],
#        [0.41055602],
#        [0.40083635],
#        [0.39198655],
#        [0.38558823],
#        [0.38244548],
#        [0.38289607],
#        [0.38628656],
#        [0.3911971 ],
#        [0.39658433],
#        [0.40208912],
#        [0.40765214],
#        [0.413787  ],
#        [0.4207098 ],
#        [0.42878264],
#        [0.4385094 ],
#        [0.4496885 ],
#        [0.46190965],
#        [0.47482657],
#        [0.48748958],
#        [0.49877042],
#        [0.5085462 ],
#        [0.51734644],
#        [0.52623904],
#        [0.5362655 ],
#        [0.54769826],
#        [0.55971307],
#        [0.5714377 ],
#        [0.58148944],
#        [0.588602  ],
#        [0.59203744],
#        [0.5928814 ],
#        [0.592443  ],
#        [0.59184414],
#        [0.59211576],
#        [0.5940993 ],
#        [0.5978627 ],
#        [0.6026305 ],
#        [0.6075755 ],
#        [0.6116756 ],
#        [0.61426926],
#        [0.6161245 ],
#        [0.6184571 ],
#        [0.6220907 ],
#        [0.6270276 ],
#        [0.6325882 ],
#        [0.637617  ],
#        [0.6430179 ],
#        [0.64966214],
#        [0.6574692 ],
#        [0.6662749 ],
#        [0.67570895],
#        [0.6850255 ],
#        [0.69337565],
#        [0.7001127 ],
#        [0.7050636 ],
#        [0.70882124],
#        [0.7120059 ],
#        [0.71482694],
#        [0.7167539 ],
#        [0.7174119 ],
#        [0.7169415 ],
#        [0.71618646],
#        [0.71629035],
#        [0.7179611 ],
#        [0.7219639 ],
#        [0.7285077 ],
#        [0.73697084],
#        [0.7463053 ],
#        [0.75520283],
#        [0.76319283],
#        [0.77015287],
#        [0.776602  ],
#        [0.78282166],
#        [0.78895867],
#        [0.7953178 ],
#        [0.8017401 ],
#        [0.80790675],
#        [0.81328166],
#        [0.81802493],
#        [0.8222631 ],
#        [0.82578427],
#        [0.82890964],
#        [0.8321017 ],
#        [0.8356468 ],
#        [0.84025663],
#        [0.84595746],
#        [0.85217255],
#        [0.85830826],
#        [0.86367077],
#        [0.86745244],
#        [0.8691663 ],
#        [0.86900294],
#        [0.8676566 ],
#        [0.8658372 ],
#        [0.86471194],
#        [0.86486924],
#        [0.8666444 ],
#        [0.8696074 ],
#        [0.87293816],
#        [0.8760848 ],
#        [0.8788534 ],
#        [0.8813203 ],
#        [0.8833476 ],
#        [0.8852592 ],
#        [0.88738376],
#        [0.889696  ],
#        [0.89154196],
#        [0.8922032 ],
#        [0.8895881 ],
#        [0.8822665 ],
#        [0.8703864 ],
#        [0.8546877 ],
#        [0.83635044],
#        [0.8167637 ],
#        [0.7978356 ],
#        [0.78086406],
#        [0.7665662 ],
#        [0.7547837 ],
#        [0.7453272 ],
#        [0.73829293],
#        [0.73398876],
#        [0.7332863 ],
#        [0.73545045],
#        [0.7398307 ],
#        [0.74594074],
#        [0.75391245],
#        [0.7640307 ],
#        [0.77613145],
#        [0.78972954],
#        [0.8040792 ],
#        [0.81707555],
#        [0.82607865],
#        [0.829699  ],
#        [0.8280512 ],
#        [0.82158685],
#        [0.8109028 ],
#        [0.797334  ],
#        [0.78228205],
#        [0.76771337],
#        [0.7554898 ],
#        [0.7461095 ],
#        [0.73918253],
#        [0.7343115 ],
#        [0.7313786 ],
#        [0.72935337],
#        [0.72704065],
#        [0.72376484],
#        [0.7194682 ],
#        [0.71497977],
#        [0.71085286],
#        [0.7077224 ],
#        [0.706233  ],
#        [0.7072153 ],
#        [0.71131223],
#        [0.71816665],
#        [0.72723466],
#        [0.73783815],
#        [0.7487617 ],
#        [0.75885934],
#        [0.7670111 ],
#        [0.7722465 ],
#        [0.77413166],
#        [0.7723417 ],
#        [0.7671495 ],
#        [0.7593742 ],
#        [0.74958503],
#        [0.73764014],
#        [0.7239994 ],
#        [0.7098646 ],
#        [0.6965841 ],
#        [0.68597895],
#        [0.6801051 ],
#        [0.67984134],
#        [0.6852806 ],
#        [0.69584423],
#        [0.7104336 ],
#        [0.7274999 ],
#        [0.7459662 ],
#        [0.7644819 ],
#        [0.78227365],
#        [0.79876363],
#        [0.81372195],
#        [0.8268853 ],
#        [0.83834136],
#        [0.8479914 ],
#        [0.85586005],
#        [0.8617851 ],
#        [0.8657135 ],
#        [0.8678794 ],
#        [0.8684276 ],
#        [0.867701  ],
#        [0.86638737],
#        [0.8647097 ],
#        [0.8635885 ],
#        [0.86338925],
#        [0.8644677 ],
#        [0.86709267],
#        [0.87071085],
#        [0.8748952 ],
#        [0.87974304],
#        [0.8852225 ],
#        [0.8909779 ],
#        [0.8962804 ],
#        [0.90073997],
#        [0.9038359 ],
#        [0.9053304 ],
#        [0.9051058 ],
#        [0.9031708 ],
#        [0.89990026],
#        [0.8959019 ]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([0.01186803])

# %%
scale_factor = 1/0.02123255
y_predicted = y_predicted * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test , 'b' , label = 'Original Price' )
plt.plot(y_predicted , 'r' , label = 'Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
